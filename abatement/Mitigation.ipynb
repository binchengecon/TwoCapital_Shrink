# %% [markdown]
# $$
# d \log K = (\mu_k + i - \frac{\kappa}{2} i^2 - \frac{\sigma_k^2}{2}) dt + \sigma_k dW
# $$
#
# $$
# d Y = E(\theta_\ell dt + \varsigma dW)
# $$
#
# $$
# d\log \mathcal{I}_g = - \zeta dt + \Psi_0 (\frac{X}{\mathcal{I}})^{\Psi_1} dt - \frac{\sigma_g^2}{2} dt + \sigma_g dW
# $$
#
# \begin{figure}[hbt]
#     \centering
#     \tikzstyle{block} = [rectangle, draw,
#      text centered, rounded corners]
#     \tikzstyle{line} = [draw, -latex']
#     \begin{tikzpicture}[scale=2, node distance = 7cm]
#
#     \node [block] (pre1) {Pre-damage, tech I, $\Phi^{I}$};
#     \node [block, right of= pre1] (pre2) {Pre-damage, tech III, $\Phi^{III}$};
#     \node [block, below of = pre1,node distance=2.5cm] (post1) {Post-damage, tech I, $\Phi^{(m,I)}$};
#     \node [block, below of = pre2,node distance=2.5cm] (post2) {Post-damage, tech III, $\Phi^{(m,III)}$};
#     % \node [block, below of = post2] (postt) {Post-damage}
#
#     % Draw edges
#     \path [line] (line1) (pre1) -- (pre2);
#     \path [line] (pre1) -- (post1);
#     \path [line] (pre2) -- (post2);
#     \path [line] (post1) -- (post2);
# \end{tikzpicture}
#     \caption{Damage jump and technology jump}
#     \label{fig:my_label}
# \end{figure}
#
#
# $$
# \begin{align*}
# 0 = \max_{i,e} \min_{\omega_\ell, \sum_{\ell = 1}^L \omega_\ell = 1 } &   - \delta V(k,y) +  \delta \log \left( \alpha - i -  \alpha \overline{\vartheta} \left[ 1 - \left(\frac {e} { \alpha \overline\lambda \exp(k)} \right) \right]^\theta \right) + \delta k \cr
# & + \frac {\partial V(k,y)}{\partial k}
#  \left[ \mu_k    + i   -
# {\frac { \kappa} 2} i^2  -  \frac  {|\sigma_k|^2}  2\right]  + \frac {|\sigma_k|^2} 2  \frac {\partial^2 V(k,y)}{\partial k^2} \cr
# & + \frac {\partial  V(k,y)}{\partial y}  \sum_{\ell=1}^L \omega_\ell  \theta_\ell {e} + {\frac 1 2} \frac {\partial^2 V(k,y)}{\partial y^2} |\varsigma|^2 e^2  \cr
# & - \left( \left[ \gamma_1 + \gamma_2 y + \gamma_3^m (y - \overline y) \right]   \sum_{\ell=1}^L \omega_\ell \theta_\ell { e} + {\frac 1 2} (\gamma_2 +
# \gamma_3^m) |\varsigma|^2  e^2 \right) \cr
# & + \xi_a \sum_{\ell = 1}^L \omega_\ell \left( \log \omega_\ell - \log \pi_\ell \right) \\
# & + \frac{\partial V}{\partial \mathcal{I}_g} (- \zeta + \Psi_0 x^{\Psi_1} - \frac{\sigma_g^2}{2} ) + \frac{\sigma_g^2}{2}\frac{\partial^2 V}{\partial \mathcal{I}_g^2} \\
# & + \xi_a \sum_{\ell = 1}^L \omega_\ell \left( \log \omega_\ell - \log \pi_\ell \right) \\
# & + \xi_g \mathcal{I}_g \left(1 - g + g  \log(g) \right) + \mathcal{I}_g g (V^{\text{post tech, m}} - V )
# \end{align*}
# $$
#
#
# # PRE DAMAGE HJB
#
#
# # Tech level $\mathbf{III}$,  pre damage
#
#
#
#
# $$
# \begin{align*}
# 0 = \max_{i,e} \min_{\omega_\ell, \sum_{\ell = 1}^L \omega_\ell = 1 } &   - \delta V(k,y) +  \delta \log \left( \alpha - i\right) + \delta k \cr
# & + \frac {\partial V(k,y)}{\partial k}
#  \left[ \mu_k    + i   -
# {\frac { \kappa} 2} i^2  -  \frac  {|\sigma_k|^2}  2\right]  + \frac {|\sigma_k|^2} 2  \frac {\partial^2 V(k,y)}{\partial k^2} \cr
# & + \sum_{m=1}^M \pi_d^m g_m (V^m - V) + \xi_d \sum_{m=1}^M \pi_d g_m (1 - g_m + g_m \log(g_m))
# \end{align*}
# $$
#
#
# Let
#
# $$
# mc \doteq  \frac \delta {\left( \alpha - i -   \alpha \overline{\vartheta} \left[ 1 - \left({\frac {e} { \alpha \overline\lambda \exp(k)}}\right) \right]^\theta  \right)}
# $$
#
# First-order conditions for $i$:
#
# $$
# - mc + \frac {\partial \Phi^m(k,y)}{\partial k} \left( 1 - \kappa i \right) = 0.
# $$
#
# Given $mc$, the first-order conditions for $i$ are affine.
# First-order conditions for $e$:
#
# $$
# \begin{align*}
#  & mc  \left( \frac{\theta {\overline \vartheta}}{ \overline \lambda} \left[1 - \left({\frac {e} { \alpha \overline\lambda \exp(k)}}\right)  \right]^{\theta - 1}\right) \exp(-k)  \cr
#  &+  \frac {\partial  \Phi^m(k,y)}{\partial y}  \sum_{\ell=1}^L \omega_\ell  \theta_\ell  + \frac {\partial^2 \Phi^m(k,y)}{\partial y^2} |\varsigma|^2 e \cr
#  & -  \left( \left[ \gamma_1 + \gamma_2 y + \gamma_3^m (y - \overline y) \right]   \sum_{\ell=1}^L \omega_\ell \theta_\ell  + (\gamma_2 +
# \gamma_3^m) |\varsigma|^2 e \right) = 0
# \end{align*}
# $$
#
#
# # Tech level $\mathbf{II} \to \mathbf{III}$, pre damage
#
# $$\bar{\vartheta}  = \bar{\vartheta}_2 = 0.0453 / 2$$
# $$\bar{\lambda} = \bar{\lambda}_2 = 0.1206 /2 $$
#
#
#
# $$
# x = \frac{X}{K}
# $$
#
# $$
# \begin{align*}
# 0 = \max_{i,e} \min_{\omega_\ell, \sum_{\ell = 1}^L \omega_\ell = 1, h } &   - \delta V(k,y, \mathcal{I}_g) +  \delta \log \left( \alpha - i -  \alpha \overline{\vartheta} \left[ 1 - \left(\frac {e} { \alpha \overline\lambda \exp(k)} \right) \right]^\theta  - x \right) + \delta k \cr
# & + \frac {\partial V(k,y)}{\partial k}
#  \left[ \mu_k    + i   -
# {\frac { \kappa} 2} i^2  -  \frac  {|\sigma_k|^2}  2\right]  + \frac {|\sigma_k|^2} 2  \frac {\partial^2 V(k,y)}{\partial k^2} \cr
# & + \frac {\partial  V(k,y)}{\partial y}  \sum_{\ell=1}^L \omega_\ell  \theta_\ell {e} + {\frac 1 2} \frac {\partial^2 V(k,y)}{\partial y^2} |\varsigma|^2 e^2  \cr
# & - \left( \left[ \gamma_1 + \gamma_2 y\right]   \sum_{\ell=1}^L \omega_\ell \theta_\ell { e} + {\frac 1 2} (\gamma_2 ) |\varsigma|^2  e^2 \right) \cr
# & + \frac{\partial V}{\partial \mathcal{I}_g} (- \zeta + \Psi_0 x^{\Psi_1} - \frac{\sigma_g^2}{2} ) + \frac{\sigma_g^2}{2}\frac{\partial^2 V}{\partial \mathcal{I}_g^2} \\
# & + \xi_a \sum_{\ell = 1}^L \omega_\ell \left( \log \omega_\ell - \log \pi_\ell \right) \\
# & + \xi_g \mathcal{I}_g \left(1 - g + g  \log(g) \right) + \mathcal{I}_g g (V^{\text{post tech, m}} - V )\\
# & + \sum_{m=1}^M \pi_d^m g_m (V^m - V) + \xi_d \sum_{m=1}^M \pi_d g_m (1 - g_m + g_m \log(g_m))
# \end{align*}
# $$
#
# # Tech level $\mathbf{I} \to \mathbf{II}$, pre damage
#
# $$\bar{\vartheta}  = \bar{\vartheta}_2 = 0.0453$$
# $$\bar{\lambda} = \bar{\lambda}_2 = 0.1206$$
#
#
#
# $$
# x = \frac{X}{K}
# $$
#
# $$
# \begin{align*}
# 0 = \max_{i,e} \min_{\omega_\ell, \sum_{\ell = 1}^L \omega_\ell = 1, h } &   - \delta V(k,y, \mathcal{I}_g) +  \delta \log \left( \alpha - i -  \alpha \overline{\vartheta} \left[ 1 - \left(\frac {e} { \alpha \overline\lambda \exp(k)} \right) \right]^\theta  - x \right) + \delta k \cr
# & + \frac {\partial V(k,y)}{\partial k}
#  \left[ \mu_k    + i   -
# {\frac { \kappa} 2} i^2  -  \frac  {|\sigma_k|^2}  2\right]  + \frac {|\sigma_k|^2} 2  \frac {\partial^2 V(k,y)}{\partial k^2} \cr
# & + \frac {\partial  V(k,y)}{\partial y}  \sum_{\ell=1}^L \omega_\ell  \theta_\ell {e} + {\frac 1 2} \frac {\partial^2 V(k,y)}{\partial y^2} |\varsigma|^2 e^2  \cr
# & - \left( \left[ \gamma_1 + \gamma_2 y\right]   \sum_{\ell=1}^L \omega_\ell \theta_\ell { e} + {\frac 1 2} (\gamma_2 ) |\varsigma|^2  e^2 \right) \cr
# & + \frac{\partial V}{\partial \mathcal{I}_g} (- \zeta + \Psi_0 x^{\Psi_1} - \frac{\sigma_g^2}{2} ) + \frac{\sigma_g^2}{2}\frac{\partial^2 V}{\partial \mathcal{I}_g^2} \\
# & + \xi_a \sum_{\ell = 1}^L \omega_\ell \left( \log \omega_\ell - \log \pi_\ell \right) \\
# & + \xi_g \mathcal{I}_g \left(1 - g + g  \log(g) \right) + \mathcal{I}_g g (V^{\text{post tech, m}} - V )\\
# & + \sum_{m=1}^M \pi_d^m g_m (V^m - V) + \xi_d \sum_{m=1}^M \pi_d g_m (1 - g_m + g_m \log(g_m))
# \end{align*}
# $$
#
# Let
#
# $$
# mc \doteq  \frac \delta {\left( \alpha - i -   \alpha \overline{\vartheta} \left[ 1 - \left({\frac {e} { \alpha \overline\lambda \exp(k)}} \right) \right]^\theta - x \right)}
# $$
#
# First-order conditions for $i$:
#
# $$
# - mc + \frac {\partial V(k,y)}{\partial k} \left( 1 - \kappa i \right) = 0.
# $$
#
# Given $mc$, the first-order conditions for $i$ are affine.
# First-order conditions for $e$:
#
# $$
# \begin{align*}
#  & mc  \left( \frac{\theta {\overline \vartheta}}{ \overline \lambda} \left[1 - \left({\frac {e} { \alpha \overline\lambda \exp(k)}}\right)  \right]^{\theta - 1}\right) \exp(-k)  \cr
#  &+  \frac {\partial  V(k,y)}{\partial y}  \sum_{\ell=1}^L \omega_\ell  \theta_\ell  + \frac {\partial^2 V(k,y)}{\partial y^2} |\varsigma|^2 e \cr
#  & - \left( \left[ \gamma_1 + \gamma_2 y + \gamma_3^m (y - \overline y) \right]   \sum_{\ell=1}^L \omega_\ell \theta_\ell  + (\gamma_2 +
# \gamma_3^m) |\varsigma|^2 e \right) = 0
# \end{align*}
# $$
#
#
#
#
# Given $mc$ and $\theta = 3$, the first-order conditions for $e$ are affine. Update $e$ according to the formula above.
#
# First order condition for $x$:
#
# $$
#  mc = \psi_0 \psi_1 (\frac{K}{L})^{\psi_1} x^{\psi_1 - 1} \frac{\partial V}{\partial \log(\mathcal{I}_g)}
# $$
#
#
# | Parameter | Value|
# |----|---|
# |$\theta$ | 3|
# | $\psi_1$  | 0.5|
# | $\psi_0$  | 0.005|
# |$\bar{\vartheta}$| 0.0453|
# |$\bar{\lambda}$ | 0.1206|

# %% [markdown]
# %%dot
#
# digraph apply {
#   rankdir=BT; fontname=Helvetica
#   node[peripheries=0, style=filled, fillcolor=blue, fontcolor=white,fontname=Helvetica,fixedsize=true,width=1.8,height=0.8]
#   edge[fontname=Helvetica,fontsize=12,fontcolor=blue,labeldistance=1.8]
#
#   subgraph cluster_student {
#     label="Student";
#     style=filled; fillcolor=grey92
#     submit [shape=record, style="filled,rounded",label="Submit\nRegistration\n"]
#     letter [shape=box, peripheries=0, label="Letter"]
#   }
#   subgraph cluster_admin {
#     label="Admin"
#     style=filled; fillcolor=grey92
#     complete  [shape=diamond, height=1.5, label="Application\nComplete?"]
#     admreject [shape=record, label="Write Rejection\nLetter\n"]
#   }
#   subgraph cluster_registrar {
#     label="Registrar"
#     style=filled; fillcolor=grey92
#     min [shape=diamond, height=1.8, label="Minimum\nStandard\nMet?"]
#   }
#   subgraph cluster_faculty {
#     label="Faculty"
#     style=filled; fillcolor=grey92
#     {rank=same;
#     suitable  [shape=diamond, height=1.8,label="Suitable for\nProgram?\n"]
#     facaccept [shape=record,  label="Write Acceptance\nLetter\n"]
#     }
#   }
#
#   submit -> complete
#   complete -> submit     [headlabel="no"]
#   complete -> min        [headlabel="yes"]
#   min -> admreject       [headlabel="no"]
#   min -> suitable        [headlabel="yes"]
#   suitable -> admreject  [headlabel="no"]
#   suitable -> facaccept  [headlabel="yes"]
#   admreject -> letter
#   facaccept -> letter
# }
